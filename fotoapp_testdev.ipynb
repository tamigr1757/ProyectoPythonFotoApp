# %%
import fotoapp

fotoapp.menuMain()
# Out:
# Bienvenido a la aplicacion de FotoApp. Antes de comenzar, debemos establecer la ruta donde estan sus imagenes.
# Ahora, debemos establecer la imagen con la cual vamos a trabajar
# Ahora, debemos redimensionar la imagen acorde a alguno de los formatos disponibles
# Formatos disponibles:
# 	youtube
# 	instagram
# 	twitter
# 	facebook
#
# Que quiere hacer ahora con la imagen?
# 1. Normalizar histograma
# 2. Filtrar imagen
# 3. Buscar bordes
# 4. Salir del programa
#
# Que quiere hacer ahora con la imagen?
# 1. Normalizar histograma
# 2. Filtrar imagen
# 3. Buscar bordes
# 4. Salir del programa
# Filtros disponibles:
# 	none
# 	blur
# 	contour
# 	detail
# 	edge_enhance
# 	edge_enhance_more
# 	emboss
# 	find_edges
# 	sharpen
# 	smooth
#
# Que quiere hacer ahora con la imagen?
# 1. Normalizar histograma
# 2. Filtrar imagen
# 3. Buscar bordes
# 4. Salir del programa
#
# Que quiere hacer ahora con la imagen?
# 1. Normalizar histograma
# 2. Filtrar imagen
# 3. Buscar bordes
# ...
